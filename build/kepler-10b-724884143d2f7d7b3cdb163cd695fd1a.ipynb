# %%
from exoatlas import *

# %%
e = TransitingExoplanets()
k = e['Kepler-10b']

# %%
e['Kepler-10'].create_table(['name', 'radius', 'period'])
# Out:
# <QTable length=2>
#     name     radius    period
#             earthRad     d
#    str29    float64   float64
# ----------- -------- ---------
# Kepler-10 b     1.47 0.8374907
# Kepler-10 c    2.355 45.294301

# %%
kw = dict(f=.667, albedo=0, wavelength=7*u.micron)
k.emission_signal(**kw)*1e6
# Out:
# <Quantity [ 64.96180789]>

# %%
k.emission_snr(per_transit=True, R=10, **kw)
# Out:
# <Quantity [ 1.47988031]>

# %%
k.depth_uncertainty(per_transit=True, R=10, **kw)*1e6
# Out:
# <Quantity [ 43.89666341]>
