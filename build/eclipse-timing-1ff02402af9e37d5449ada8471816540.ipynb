# %%
from exoatlas import * 
from astroplan import Observer
from astropy.time import Time 

e = TransitingExoplanets()
single_planet = e['TOI-2109b']
single_planet

t = single_planet.show_upcoming_transits(where=Observer.at_site("APO", timezone="US/Mountain"),
                                     when=Time('2026-04-01'), 
                                     window=90*u.day, 
                                     orbital_phase=0.5, 
                                     allow_partial_transits=True)
t
# Out:
# <QTable length=36>
#    name    orbital_phase           date          ... stellar_radius distance
#                                                  ...     solRad        pc
#   str29       float64             str23          ...    float64     float64
# ---------- ------------- ----------------------- ... -------------- --------
# TOI-2109 b           0.5 2026-04-01 10:27:23.620 ...          1.698  262.041
# TOI-2109 b           0.5 2026-04-03 10:52:28.917 ...          1.698  262.041
# TOI-2109 b           0.5 2026-04-05 11:17:34.214 ...          1.698  262.041
# TOI-2109 b           0.5 2026-04-07 11:42:39.512 ...          1.698  262.041
# TOI-2109 b           0.5 2026-04-18 05:56:27.763 ...          1.698  262.041
# TOI-2109 b           0.5 2026-04-20 06:21:33.060 ...          1.698  262.041
# TOI-2109 b           0.5 2026-04-22 06:46:38.357 ...          1.698  262.041
# TOI-2109 b           0.5 2026-04-24 07:11:43.654 ...          1.698  262.041
# ...

# %%
t = single_planet.show_upcoming_transits(where=Observer.at_site("APO", timezone="US/Mountain"),
                                     when=Time('2026-04-01'), 
                                     window=90*u.day, 
                                     orbital_phase=0.5, 
                                     allow_partial_transits=False)
t
# Out:
# <QTable length=36>
#    name    orbital_phase           date          ... stellar_radius distance
#                                                  ...     solRad        pc
#   str29       float64             str23          ...    float64     float64
# ---------- ------------- ----------------------- ... -------------- --------
# TOI-2109 b           0.5 2026-04-01 10:27:23.620 ...          1.698  262.041
# TOI-2109 b           0.5 2026-04-03 10:52:28.917 ...          1.698  262.041
# TOI-2109 b           0.5 2026-04-05 11:17:34.214 ...          1.698  262.041
# TOI-2109 b           0.5 2026-04-07 11:42:39.512 ...          1.698  262.041
# TOI-2109 b           0.5 2026-04-18 05:56:27.763 ...          1.698  262.041
# TOI-2109 b           0.5 2026-04-20 06:21:33.060 ...          1.698  262.041
# TOI-2109 b           0.5 2026-04-22 06:46:38.357 ...          1.698  262.041
# TOI-2109 b           0.5 2026-04-24 07:11:43.654 ...          1.698  262.041
# ...
