# %%
from exoatlas.models import *

# %%
m = Mamajek()

# %%
m.plot(['logT', 'logL', 'logR', 'logM'])

# %%
m.table.rename(columns={'R_Rsun':'radius', 
                        'Msun':'mass'}).drop(columns='SpT2')
# Out:
#        SpT   Teff   logT   BCv  logL  Mbol  radius    Mv    B-V  Bt-Vt  ...  \
# 0      O3V  44900  4.652 -4.01  5.82 -9.81   13.43 -5.80 -0.330    NaN  ...
# 1      O4V  42900  4.632 -3.89  5.65 -9.39   12.13 -5.50 -0.326    NaN  ...
# 2      O5V  41400  4.617 -3.76  5.54 -9.11   11.45 -5.35 -0.323    NaN  ...
# 3    O5.5V  40500  4.607 -3.67  5.44 -8.87   10.71 -5.20 -0.322    NaN  ...
# 4      O6V  39500  4.597 -3.57  5.36 -8.67   10.27 -5.10 -0.321    NaN  ...
# ..     ...    ...    ...   ...   ...   ...     ...   ...    ...    ...  ...
# 113  Y0.5V    400  2.602   NaN   NaN   NaN     NaN   NaN    NaN    NaN  ...
# 114    Y1V    360  2.556   NaN   NaN   NaN     NaN   NaN    NaN    NaN  ...
# 115  Y1.5V    325  2.512   NaN   NaN   NaN     NaN   NaN    NaN    NaN  ...
# 116    Y2V    320  2.505   NaN   NaN   NaN     NaN   NaN    NaN    NaN  ...
# 117    Y4V    250  2.398   NaN   NaN   NaN     NaN   NaN    NaN    NaN  ...
#
# ...

# %%
m.table.columns
# Out:
# Index(['SpT', 'Teff', 'logT', 'BCv', 'logL', 'Mbol', 'R_Rsun', 'Mv', 'B-V',
#        'Bt-Vt', 'G-V', 'Bp-Rp', 'G-Rp', 'M_G', 'b-y', 'U-B', 'V-Rc', 'V-Ic',
#        'V-Ks', 'J-H', 'H-Ks', 'M_J', 'M_Ks', 'Ks-W1', 'W1-W2', 'W1-W3',
#        'W1-W4', 'g-r', 'i-z', 'z-Y', 'Msun', 'SpT2', 'V-J'],
#       dtype='object')

# %%
i = m.tofrom('logT')('logL')
logL = np.linspace(-6, 6)
plt.plot(logL, i(logL))
plt.xlabel('logL')
plt.ylabel('logT')
# Out:
# creating interpolator to convert logL to logT
# Text(0, 0.5, 'logT')

# %%
# Out:
# plotted logT to logT
# creating interpolator to convert logL to logT
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 m.plot(['logT', 'logL', 'R_Rsun'])
#
# File ~/Dropbox/zach/code/exoatlas/exoatlas/models/relation.py:196, in Relation.plot(self, keys)
#     194 self.ax = plt.subplot(gs[i, j])
#     195 # try:
# --> 196 self.plotone(inkey, outkey)
#     197 print("plotted {0} to {1}".format(inkey, outkey))
#     198 # except:
#     199 #    print("failed to plot {0} to {1}".format(inkey, outkey))
#
# File ~/Dropbox/zach/code/exoatlas/exoatlas/models/relation.py:168, in Relation.plotone(self, inkey, outkey)
#     166 ok = np.isfinite(self.table[inkey])
#     167 realx, realy = self.table[inkey][ok], self.table[outkey][ok]
# --> 168 i = np.argost(realx)
#     169 self.ax.plot(realx[i], realy[i], marker="o", alpha=0.5, color="black")
# ...

# %%
m.plotone('logT', 'logL')
plt.show()
# Out:
# creating interpolator to convert logT to logL
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 m.plotone('logT', 'logL')
#       2 plt.show()
#
# File ~/Dropbox/zach/code/exoatlas/exoatlas/models/relation.py:168, in Relation.plotone(self, inkey, outkey)
#     166 ok = np.isfinite(self.table[inkey])
#     167 realx, realy = self.table[inkey][ok], self.table[outkey][ok]
# --> 168 i = np.argost(realx)
#     169 self.ax.plot(realx[i], realy[i], marker="o", alpha=0.5, color="black")
#     170 self.ax.set_xlabel(inkey)
#
# File ~/miniconda3/envs/exoatlas/lib/python3.13/site-packages/numpy/__init__.py:414, in __getattr__(attr)
#     411     import numpy.char as char
#     412     return char.chararray
# --> 414 raise AttributeError("module {!r} has no attribute "
#     415                      "{!r}".format(__name__, attr))
#
# ...

# %%
    stars = Mamajek()
