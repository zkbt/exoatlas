# %%
from exoatlas import *

# %%
t = Table(dict(ra=[0*u.deg], dec=[0*u.deg], name=['star-b'], hostname=['star']))
Population(standard=t)
# Out:
# ✨ None | 1 elements ✨

# %%
# Out:
# ✨ None | 1 elements ✨
