# %%
from exoatlas import *

# %%
def test_show_upcoming_transits():
    e = TransitingExoplanets()
    nearby = e[e.distance() < 15*u.pc]
    transits = nearby.show_upcoming_transits(window=10*u.day)
test_show_upcoming_transits()
