# %%
from exoatlas import * 

# create some populations
exo = TransitingExoplanets() 
sol = SolarSystem() 
fav = exo['LTT1445A']
# update parameters from a preferred source
fav.load_individual_references()
fav.display_individual_references()
# Out:
# Loaded standardized table from /Users/zabe0091/exoatlas-data/data/standardized-Exoplanets.txt
# Loaded standardized table from /Users/zabe0091/exoatlas-data/data/standardized-SolarSystem.txt
# (loading individual references may take up to a few minutes)
# Loaded standardized table from /Users/zabe0091/exoatlas-data/data/standardized-ExoplanetsPS.txt
# <QTable length=10>
# is_being_used     name     ... stellar_teff_upper_limit
#                            ...
#      str2        str29     ...         float64
# ------------- ------------ ... ------------------------
#            🗺️ LTT 1445 A b ...                      nan
#            🏷️ LTT 1445 A b ...                      nan
#            🏷️ LTT 1445 A b ...                      nan
#            🏷️ LTT 1445 A b ...                      nan
#            🏷️ LTT 1445 A b ...                      nan
#            🏷️ LTT 1445 A b ...                      nan
#            🏷️ LTT 1445 A b ...                      nan
# ...

# %%
fav.update_reference('Pass et al. 2023', verbose=True)
# Out:
# 'stellar_radius' for 'ltt1445ab'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/miniconda3/envs/exoatlas/lib/python3.13/site-packages/astropy/units/quantity.py:1697, in Quantity._to_own_unit(self, value, check_precision, unit)
#    1696 try:
# -> 1697     _value = value.to_value(unit)
#    1698 except AttributeError:
#    1699     # We're not a Quantity.
#    1700     # First remove two special cases (with a fast test):
#    1701     # 1) Maybe masked printing? MaskedArray with quantities does not
#    1702     # work very well, but no reason to break even repr and str.
#    1703     # 2) np.ma.masked? useful if we're a MaskedQuantity.
#
# AttributeError: 'numpy.float64' object has no attribute 'to_value'
#
# During handling of the above exception, another exception occurred:
#
# UnitConversionError                       Traceback (most recent call last)
# ...

# %%
help(fav.standard)
# Out:
# Help on QTable in module astropy.table.table object:
#
# class QTable(Table)
#  |  QTable(
#  |      data=None,
#  |      masked=False,
#  |      names=None,
#  |      dtype=None,
#  |      meta=None,
#  |      copy=True,
#  |      rows=None,
#  |      copy_indices=True,
#  |      units=None,
#  |      descriptions=None,
#  |      **kwargs
#  |  )
#  |
#  |  A class to represent tables of heterogeneous data.
#  |
#  |  `~astropy.table.QTable` provides a class for heterogeneous tabular data
#  |  which can be easily modified, for instance adding columns or new rows.
#  |
#  |  The `~astropy.table.QTable` class is identical to `~astropy.table.Table`
#  |  except that columns with an associated ``unit`` attribute are converted to
#  |  `~astropy.units.Quantity` objects.
#  |
#  |  For more information see:
#  |
#  |  - https://docs.astropy.org/en/stable/table/
#  |  - https://docs.astropy.org/en/stable/table/mixin_columns.html
#  |
#  |  Parameters
#  |  ----------
# ...

# %%
fav.standard
# Out:
# <QTable length=2>
#     name      hostname  letter ... obliquity_reference  tidyname tidyhostname
#                                ...
#    str29       str27     str1  ...        str25          str24      str22
# ------------ ---------- ------ ... ------------------- --------- ------------
# LTT 1445 A b LTT 1445 A      b ...                  -- ltt1445ab     ltt1445a
# LTT 1445 A c LTT 1445 A      c ...                  -- ltt1445ac     ltt1445a

# %%
fav.individual_references.standard
# Out:
# <QTable length=8>
#     name      hostname  letter ... default_parameter_set  tidyname tidyhostname
#                                ...
#    str29       str27     str1  ...         int64           str24      str22
# ------------ ---------- ------ ... --------------------- --------- ------------
# LTT 1445 A b LTT 1445 A      b ...                     0 ltt1445ab     ltt1445a
# LTT 1445 A b LTT 1445 A      b ...                     1 ltt1445ab     ltt1445a
# LTT 1445 A b LTT 1445 A      b ...                     0 ltt1445ab     ltt1445a
# LTT 1445 A b LTT 1445 A      b ...                     0 ltt1445ab     ltt1445a
# LTT 1445 A b LTT 1445 A      b ...                     0 ltt1445ab     ltt1445a
# LTT 1445 A b LTT 1445 A      b ...                     0 ltt1445ab     ltt1445a
# LTT 1445 A c LTT 1445 A      c ...                     1 ltt1445ac     ltt1445a
# LTT 1445 A c LTT 1445 A      c ...                     0 ltt1445ac     ltt1445a
